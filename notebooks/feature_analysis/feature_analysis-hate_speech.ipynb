# %%
from utils.utils import process_txt_files, plot_categorical_distribution, get_stat_significance_bootstrap
import pandas as pd
import numpy as np
from datasets import load_dataset

data_load = load_dataset("odegiber/hate_speech18", trust_remote_code=True)
# Out:
# Downloading builder script:   0%|          | 0.00/3.41k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/5.61k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/3.19M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/10944 [00:00<?, ? examples/s]

# %%
df_hate = process_txt_files('../../data/outputs/hate_speech', 'hate')
load_dataset = pd.DataFrame(data_load['train'])
#load_dataset_test = pd.DataFrame(data_load['test'])
#load_dataset = pd.concat([load_dataset, load_dataset_test], axis=0)
df_hate['label'] = list(load_dataset['label'])[:len(df_hate)]
df_hate = df_hate.drop(columns=["id", "custom_id"])

# %%
df_hate
# Out:
#       Presence of Racial Slurs Mention of Ethnic Groups Sentiment Polarity  \
# 0                           No                       No            Neutral
# 1                           No                       No            Neutral
# 2                           No                       No            Neutral
# 3                           No                      Yes           Negative
# 4                           No                       No            Neutral
# ...                        ...                      ...                ...
# 10939                       No                      Yes           Negative
# 10940                       No                      Yes           Negative
# 10941                      Yes                       No           Negative
# 10942                       No                      Yes            Neutral
# 10943                       No                       No           Positive
#
#       Use of Violent Language Presence of Hate Symbols Use of Sarcasm  \
# 0                          No                       No             No
# 1                          No                       No             No
# 2                          No                       No             No
# 3                         Yes                       No             No
# 4                          No                       No             No
# ...                       ...                      ...            ...
# 10939                      No                       No            Yes
# 10940                      No                       No             No
# 10941                      No                       No            Yes
# 10942                      No                       No             No
# 10943                      No                       No             No
#
#       Text Length Use of Expletives Grammatical Errors  \
# 0          Medium                No                 No
# 1          Medium                No                 No
# 2           Short                No                 No
# 3            Long                No                 No
# 4           Short                No                 No
# ...           ...               ...                ...
# 10939      Medium                No                 No
# 10940       Short                No                 No
# 10941      Medium                No                 No
# 10942      Medium                No                 No
# 10943       Short                No                 No
#
#       Use of First-Person Pronouns  ... Use of Third-Person Pronouns  \
# 0                               No  ...                          Yes
# 1                              Yes  ...                           No
# 2                               No  ...                           No
# 3                               No  ...                          Yes
# 4                               No  ...                           No
# ...                            ...  ...                          ...
# 10939                          Yes  ...                          Yes
# 10940                          Yes  ...                           No
# 10941                           No  ...                           No
# 10942                          Yes  ...                          Yes
# 10943                          Yes  ...                           No
#
#       Presence of Questions Presence of Negations Use of Hyperbolic Language  \
# 0                        No                    No                         No
# 1                        No                    No                         No
# 2                        No                    No                         No
# 3                        No                    No                        Yes
# 4                        No                    No                         No
# ...                     ...                   ...                        ...
# 10939                    No                   Yes                         No
# 10940                    No                    No                         No
# 10941                    No                    No                        Yes
# 10942                   Yes                   Yes                         No
# 10943                    No                    No                         No
#
#       Presence of Emotive Language Use of Metaphors Presence of Direct Quotes  \
# 0                               No               No                        No
# 1                               No               No                        No
# 2                               No               No                        No
# 3                              Yes               No                        No
# 4                               No               No                        No
# ...                            ...              ...                       ...
# 10939                          Yes               No                       Yes
# 10940                          Yes               No                        No
# 10941                          Yes               No                        No
# 10942                           No               No                        No
# 10943                          Yes               No                        No
#
#       Use of Capitalization for Emphasis Presence of Lists label
# 0                                     No                No     0
# 1                                     No                No     0
# 2                                     No                No     0
# 3                                    Yes                No     1
# 4                                     No                No     0
# ...                                  ...               ...   ...
# 10939                                 No                No     0
# 10940                                 No                No     0
# 10941                                 No               Yes     0
# 10942                                 No                No     1
# 10943                                 No                No     0
#
# [10944 rows x 21 columns]

# %%
for col in df_hate.drop(columns = ['label']).columns:
    get_stat_significance_bootstrap(df_hate, col, 'label')
    plot_categorical_distribution(df_hate, 'label', col)
# Out:
# Original P-value: 0.0
# Bootstrap Mean P-value: 0.0
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.45234787763273077
# Effect Size: Strong association
# Significant association between Presence of Racial Slurs and label.
# ---------------------------------------------------------------
# Original P-value: 1.6890664072489825e-188
# Bootstrap Mean P-value: 2.9469087591090493e-151
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.2821187921572966
# Effect Size: Moderate association
# Significant association between Mention of Ethnic Groups and label.
# ---------------------------------------------------------------
# Original P-value: 0.0
# Bootstrap Mean P-value: 8.326463385321043e-297
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.27046273830269807
# Effect Size: Moderate association
# Significant association between Sentiment Polarity and label.
# ---------------------------------------------------------------
# Original P-value: 4.175015435139934e-151
# Bootstrap Mean P-value: 1.6620046481535435e-106
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.25265817214476965
# Effect Size: Moderate association
# Significant association between Use of Violent Language and label.
# ---------------------------------------------------------------
# Original P-value: 0.5184103273696297
# Bootstrap Mean P-value: 0.2978315919400258
# Relationship is significant in 317/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.01440013363996019
# Effect Size: Weak association
# No significant association between Presence of Hate Symbols and label.
# ---------------------------------------------------------------
# Original P-value: 1.2529071846636717e-10
# Bootstrap Mean P-value: 4.3777759709400055e-06
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.06696906019682534
# Effect Size: Weak association
# Significant association between Use of Sarcasm and label.
# ---------------------------------------------------------------
# Original P-value: 6.684806379517327e-58
# Bootstrap Mean P-value: 2.1454526391891336e-38
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.1134530688102637
# Effect Size: Moderate association
# Significant association between Text Length and label.
# ---------------------------------------------------------------
# Original P-value: 4.3140573882648443e-26
# Bootstrap Mean P-value: 8.651618385827324e-11
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.10522384860975231
# Effect Size: Moderate association
# Significant association between Use of Expletives and label.
# ---------------------------------------------------------------
# Original P-value: 1.2241548125835806e-28
# Bootstrap Mean P-value: 4.161407964401199e-14
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.11023709179498223
# Effect Size: Moderate association
# Significant association between Grammatical Errors and label.
# ---------------------------------------------------------------
# Original P-value: 1.6369134054085347e-19
# Bootstrap Mean P-value: 4.717639630768969e-12
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.09098082896258573
# Effect Size: Weak association
# Significant association between Use of First-Person Pronouns and label.
# ---------------------------------------------------------------
# Original P-value: 0.0001940771969428072
# Bootstrap Mean P-value: 0.002487613941018667
# Relationship is significant in 2477/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.04244789149081025
# Effect Size: Weak association
# Significant association between Use of Second-Person Pronouns and label.
# ---------------------------------------------------------------
# Original P-value: 6.429191677048988e-70
# Bootstrap Mean P-value: 1.8290206520639812e-49
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.17205528035301035
# Effect Size: Moderate association
# Significant association between Use of Third-Person Pronouns and label.
# ---------------------------------------------------------------
# Original P-value: 0.020860880612957804
# Bootstrap Mean P-value: 0.05297179232757237
# Relationship is significant in 1913/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.029840597197441445
# Effect Size: Weak association
# Significant association between Presence of Questions and label.
# ---------------------------------------------------------------
# Original P-value: 1.6447218971651634e-94
# Bootstrap Mean P-value: 1.450317371628551e-71
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.1999463016166491
# Effect Size: Moderate association
# Significant association between Presence of Negations and label.
# ---------------------------------------------------------------
# Original P-value: 8.126469574640528e-168
# Bootstrap Mean P-value: 3.633678421530066e-121
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.2662282362144605
# Effect Size: Moderate association
# Significant association between Use of Hyperbolic Language and label.
# ---------------------------------------------------------------
# Original P-value: 3.829854817343282e-216
# Bootstrap Mean P-value: 2.32680662848688e-182
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.30205312395911277
# Effect Size: Strong association
# Significant association between Presence of Emotive Language and label.
# ---------------------------------------------------------------
# Original P-value: 1.406244820468061e-23
# Bootstrap Mean P-value: 6.965653915801123e-11
# Relationship is significant in 2500/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.10002714641814477
# Effect Size: Moderate association
# Significant association between Use of Metaphors and label.
# ---------------------------------------------------------------
# Original P-value: 0.3958302889712353
# Bootstrap Mean P-value: 0.25669502577423065
# Relationship is significant in 758/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.016481562712044352
# Effect Size: Weak association
# No significant association between Presence of Direct Quotes and label.
# ---------------------------------------------------------------
# Original P-value: 0.001896106535013791
# Bootstrap Mean P-value: 0.022970599996783834
# Relationship is significant in 2222/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.03690931067439729
# Effect Size: Weak association
# Significant association between Use of Capitalization for Emphasis and label.
# ---------------------------------------------------------------
# Original P-value: 0.32789020462190904
# Bootstrap Mean P-value: 0.24660442056261705
# Relationship is significant in 439/2500 bootstrap samples.
# Cramér's V (Effect Size): 0.017743635267746
# Effect Size: Weak association
# No significant association between Presence of Lists and label.
# ---------------------------------------------------------------
